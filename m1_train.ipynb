# %%
import os
import glob
import time
import json
import hashlib
import pandas as pd

from sklearn.model_selection import train_test_split
from catboost import Pool, CatBoostClassifier

# %% [markdown]
# Обучаем модель предсказывать события M1 на основе событий M3

# %%
# цикл по эксгаустерам
for x in range(4,10):

    y_exh = pd.read_parquet('/root/sep_data/Y_exhauster%s_train.parquet' % x )
    
    cols = y_exh.columns

    # цикл по таргетам
    for target_col in cols:

        y_target = y_exh[[target_col]].copy()
    
        # по таргету в Х оставляем только события М3
        # обнуляем всё, кроме 2
        y_exh[target_col] = (y_target[target_col] == 2)*2
    
        # по таргету в y наоборот, оставляем только 1
        y_target[target_col] = (y_target[target_col] == 1)*1
    
        y = y_exh.copy()
    
        # нам нужен NaN чтобы посчитать кол-во минимум и максимум
        # 0 нам мешает
        for c in y.columns:
            y[c] = y[c]/y[c]*y[c]
    
        # в каждой строке агрегаты за 30 дней
        yy = y.rolling(window='30D').agg(['count','min', 'max'])
    
        # колонки с count делим на кол-во строк в месяце
        for c in yy.columns:
            if c[1] == 'count':
                yy[c] = yy[c]/(30*24*60*6)
    
        features = ["_".join(x) for x in yy.columns]
        
        yy.columns = features
        
        splitted_data = train_test_split(yy, y_target, test_size=0.3)
        X_train, X_test, y_train, y_test = splitted_data
    
        train_pool = Pool(X_train, y_train)
        test_pool = Pool(X_test, y_test)
    
        label_0 = y_target[ y_target[ target_col ] == 0 ].count().values[0]
        label_2 = y_target[ y_target[ target_col ] == 1 ].count().values[0]
        attitude = label_2/(label_0+label_2)
        
        # если очень маленькое отношение таргета к общему кол-ву, то пропускаем
        if attitude < 1e-05:
            print('Skipped target: %s' % target_col, attitude)
            continue
            
        print(target_col)

        # параметры подобрали через  GreedSearchCV
        model = CatBoostClassifier(learning_rate=0.01, iterations=100, depth=5, loss_function='Logloss', eval_metric='Accuracy')
        model.fit(train_pool, eval_set=test_pool, verbose=False)

        model.save_model('/root/m1_model/%s.cb' % hashlib.sha256(target_col.encode('utf-8')).hexdigest() )
        print('Accuracy', model.best_score_.get('learn').get('Accuracy'))
    
    del y_exh
# Out:
# Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №4
# Accuracy 0.9999210347870839
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_УЛИТА ЭКСГ. №4 0.0
# Y_ЭКСГАУСТЕР А/М №4_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №4
# Accuracy 0.9999917361986483
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №4 0.0
# Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОАППАРАТУРА ЭКСГ. №4
# Accuracy 0.9999906649651398
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНЫЙ №2 ЭКСГ. №4 5.141920211538597e-06
# Y_ЭКСГАУСТЕР А/М №4_ЗАДВИЖКА ЭКСГ. №4
# Accuracy 0.9998936418159367
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ГСМ ЭКСГ. №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№4 Т.1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.1 0.0
# Y_ЭКСГАУСТЕР А/М №4_РОТОР ЭКСГ. №4
# Accuracy 0.9997995263005425
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №4 0.0
# Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №4
# Accuracy 0.9999400109235211
# Y_ЭКСГАУСТЕР А/М №4_ЭКСГАУСТЕР А/М №4
# Accuracy 0.9998546183095537
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ЗАП. И РЕГ. АРМАТУРА ЭКСГ.№4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНЫЙ №1 ЭКСГ. №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_КЛ1 ТР№4 ДО ЭД ЭКСГАУСТЕРА №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_КЛ2 ТР№4 ДО ЭД ЭКСГАУСТЕРА №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ТР-Р ТМ-4000-10/6 ЭКСГ. №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ4 ВУ1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №4_МАСЛОПРОВОДЫ ЭКСГ №4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №5 0.0
# Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №5
# Accuracy 0.9999550081926408
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_КОРПУС ЭКСГ. №5 0.0
# Y_ЭКСГАУСТЕР А/М №5_ЗАДВИЖКА ЭКСГ. №5
# Accuracy 0.9999801056634127
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ №2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (РЕЗ.) ЭКСГ. №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№5 Т.1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№5 Т.3 0.0
# Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №5
# Accuracy 0.9999675569280267
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№5 Т.2 0.0
# Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ №1
# Accuracy 0.9999732191622862
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №5 0.0
# Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ1
# Accuracy 0.9999779631963955
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ГСМ ЭКСГ. №5 0.0
# Y_ЭКСГАУСТЕР А/М №5_ЭКСГАУСТЕР А/М №5
# Accuracy 0.9999822481304297
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ТСМТ-101-010-50М-80 ТЕРМОПРЕОБР.МАСЛО 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ТР-Р ТМ-4000-10/6 ЭКСГ. №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_КЛ1 ТР№5 ДО ЭД ЭКСГАУСТЕРА №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_КЛ2 ТР№5 ДО ЭД ЭКСГАУСТЕРА №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №5 0.0
# Y_ЭКСГАУСТЕР А/М №5_РОТОР ЭКСГ. №5
# Accuracy 0.9999729130955695
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_МЕТРАН-100 ДАТЧИКИ ДАВЛЕНИЯ ЭКСГ.№5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ДВИГАТЕЛЬ ПУСКОВОГО МАСЛОНАСОСА ЭКСГ. №5 0.0
# Y_ЭКСГАУСТЕР А/М №5_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №5
# Accuracy 0.9999462852912141
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_КОЖУХ МУФТЫ ЭКСГ. №5 0.0
# Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ2
# Accuracy 0.9999876042979725
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ДВИГАТЕЛЬ РЕЗЕРВНОГО МАСЛОНАСОСА ЭКСГ.№5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ТСМТ-101-010-50М-200 ТЕРМОПР.ПОДШ.Т.3 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №5_ЭКСГАУСТЕР Н-8000 А/М №5 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_КОРПУС ЭКСГ. №6 0.0
# Y_ЭКСГАУСТЕР А/М №6_ЗАДВИЖКА ЭКСГ. №6
# Accuracy 0.9993225213225204
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНЫЙ №2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_САПФИР 22 МДД РАЗРЕЖЕНИЕ В КОЛЛЕКТОРЕ 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_МАСЛОБАК ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНЫЙ №1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_КОЖУХ МУФТЫ ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_РОТОР ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ТР-Р ТМ-4000-10/6 ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГ №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_САПФИР 22 МДД ПЕРЕПАД ДАВЛ. НА ЦИКЛОНЕ 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №6 0.0
# Y_ЭКСГАУСТЕР А/М №6_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №6
# Accuracy 0.9999886755314811
# Y_ЭКСГАУСТЕР А/М №6_ЭКСГАУСТЕР А/М №6
# Accuracy 0.999986992164539
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ6 ВУ1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ДВИГАТЕЛЬ ПУСКОВОГО МАСЛОНАСОСА ЭКСГ. №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (ПУСК.) ЭКСГ.№6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№6 Т.3 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_МАСЛОПРОВОДЫ ЭКСГ №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_КЛ1 ТР№6 ДО ЭД ЭКСГАУСТЕРА №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_КЛ2 ТР№6 ДО ЭД ЭКСГАУСТЕРА №6 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №6_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№6 Т.2 0.0
# Y_ЭКСГАУСТЕР А/М №7_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №7
# Accuracy 0.9999649553609345
# Y_ЭКСГАУСТЕР А/М №7_КОРПУС ЭКСГ. №7
# Accuracy 0.9998885917151107
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНЫЙ №1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ЗАДВИЖКА ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНЫЙ №2 9.64110039663487e-06
# Y_ЭКСГАУСТЕР А/М №7_РОТОР ЭКСГ. №7
# Accuracy 0.9999791874632624
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№7 Т.3 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-80 ТЕРМОПРЕОБР.МАСЛО 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ГСМ ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_КОЖУХ МУФТЫ ЭКСГ. №7 0.0
# Y_ЭКСГАУСТЕР А/М №7_ЭКСГАУСТЕР А/М №7
# Accuracy 0.9995457969923742
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_САПФИР 22 МДД ПЕРЕПАД ДАВЛ. НА ЦИКЛОНЕ 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №7 5.141920211538597e-06
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (ПУСК.) ЭКСГ.№7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_МАСЛЯНЫЙ ФИЛЬТР ЭКСГАУСТЕРА №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ТР-Р ТМ-4000-10/6 ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-200 ТЕРМОПР.ПОДШ.Т.3 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№7 Т.2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№7 Т.4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ7 ВУ1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_КЛ1 ТР№7 ДО ЭД ЭКСГАУСТЕРА №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_МЕТРАН-100 ДАТЧИКИ ДАВЛЕНИЯ ЭКСГ.№7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_РЕГУЛИРУЮЩАЯ АППАРАТУРА ЭКСГАУСТЕРА №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №7 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.1 0.0
# Y_ЭКСГАУСТЕР А/М №8_РОТОР ЭКСГ. №8
# Accuracy 0.999546562159166
# Y_ЭКСГАУСТЕР А/М №8_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №8
# Accuracy 0.9988196537069347
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_КОРПУС ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№8 Т.3 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№8 Т.4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №8 0.0
# Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ СПВД-М10-400-5
# Accuracy 0.9999830132972215
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_КЛ2 ТР№8 ДО ЭД ЭКСГАУСТЕРА №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_КЛ1 ТР№8 ДО ЭД ЭКСГАУСТЕРА №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_КОЖУХ МУФТЫ ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ГСМ ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНЫЙ №2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ЭКСГАУСТЕР А/М №8 7.820003655048284e-06
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ТСМТ-101-010-50М-200 ТЕРМОПР.ПОДШ.Т.4 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_МАСЛЯНЫЙ ФИЛЬТР ЭКСГАУСТЕРА №8 0.0
# Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ8 ВУ1
# Accuracy 0.999973525229003
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНЫЙ №1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №8 8.35562034375022e-06
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ЗАДВИЖКА ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (РЕЗ.) ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (ПУСК.) ЭКСГ.№8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№8 Т.2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ТР-Р ТМ-6300-10/6 ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №8_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №8 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_МАСЛОСТАНЦИЯ ЖИДКОЙ СМАЗКИ ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРОАППАРАТУРА ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_КЛ1 ТР№9 ДО ЭД ЭКСГАУСТЕРА №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_КОРПУС ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №9 0.0
# Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №9
# Accuracy 0.9999828602638632
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_РОТОР ЭКСГ. №9 0.0
# Y_ЭКСГАУСТЕР А/М №9_ТР-Р ТМ-6300-10/6 ЭКСГ. №9
# Accuracy 0.9999545490925658
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНЫЙ №2 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ГСМ ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_КОЖУХ МУФТЫ ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНЫЙ №1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ЗАДВИЖКА ЭКСГ. №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№9 Т.1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ9 ВУ1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_МЕТРАН-100 ДАТЧИКИ ДАВЛЕНИЯ ЭКСГ.№9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ТСМТ-101-010-50М-80 ТЕРМОПРЕОБР.МАСЛО 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.1 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ЭКСГАУСТЕР А/М №9 0.0
# Skipped target: Y_ЭКСГАУСТЕР А/М №9_ДВИГАТЕЛЬ ПУСКОВОГО МАСЛОНАСОСА ЭКСГ. №9 0.0

# %%
with open('/root/model/Y_columns.json', 'rb') as f:
    Y_columns = json.loads( f.read().decode('utf-8') )

# %%
# загружаем наши предсказания М3
y_pred = pd.read_parquet('/root/sep_data/sep_y_pred.parquet')

# %%
y_m1 = y_pred[['DT']].copy()
y_m1.index = y_m1['DT']
del y_m1['DT']
y_pred.index = y_pred['DT']
del y_pred['DT']

# %%
y_pred_add = y_m1.copy()

# %%
# пропущенные колонки заполняем 0
for col in Y_columns:
    if col in y_pred.columns:
        y_pred_add[ col ] = y_pred[ col ]
    else:
        y_pred_add[ col ] = 0

# %%
# подготоавливаем данные
y = y_pred_add
    
for c in y.columns:
    y[c] = y[c]/y[c]*y[c]

yy = y.rolling(window='30D').agg(['count','min', 'max'])

for c in yy.columns:
    if c[1] == 'count':
        yy[c] = yy[c]/(30*24*60*6)

features = ["_".join(x) for x in yy.columns]

yy.columns = features

# %%
# диапазаны таргетов к эксгуастерам
target_col_data = {
    "exhauster4": slice(93,116), 
    "exhauster5": slice(28,62),
    "exhauster6": slice(148,175),
    "exhauster7": slice(116,148),
    "exhauster8": slice(62,93),
    "exhauster9": slice(0,28),
}

# %%
# цикл по эксгуастерам
for x in target_col_data:
    print(x)

    # цикл по таргетам
    for y in Y_columns[ target_col_data[ x ] ]:
        target_col = y

        # если есть модель, восстанавливаем
        if os.path.exists('/root/m1_model/%s.cb' % hashlib.sha256(target_col.encode('utf-8')).hexdigest() ):
            print(target_col)
            
    
            model = CatBoostClassifier(learning_rate=0.01, iterations=100, depth=5, loss_function='Logloss', eval_metric='Accuracy')
            model = model.load_model('/root/m1_model/%s.cb' % hashlib.sha256(target_col.encode('utf-8')).hexdigest() )
            
            # Делаем предсказание
            y_m1_col_perd = model.predict(yy[model.feature_names_])
            y_m1[target_col] = y_m1_col_perd
# Out:
# exhauster4
# Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №4
# Y_ЭКСГАУСТЕР А/М №4_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №4
# Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОАППАРАТУРА ЭКСГ. №4
# Y_ЭКСГАУСТЕР А/М №4_ЗАДВИЖКА ЭКСГ. №4
# Y_ЭКСГАУСТЕР А/М №4_РОТОР ЭКСГ. №4
# Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №4
# Y_ЭКСГАУСТЕР А/М №4_ЭКСГАУСТЕР А/М №4
# exhauster5
# Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №5
# Y_ЭКСГАУСТЕР А/М №5_ЗАДВИЖКА ЭКСГ. №5
# Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №5
# Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ №1
# Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ1
# Y_ЭКСГАУСТЕР А/М №5_ЭКСГАУСТЕР А/М №5
# Y_ЭКСГАУСТЕР А/М №5_РОТОР ЭКСГ. №5
# Y_ЭКСГАУСТЕР А/М №5_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №5
# Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ2
# exhauster6
# Y_ЭКСГАУСТЕР А/М №6_ЗАДВИЖКА ЭКСГ. №6
# Y_ЭКСГАУСТЕР А/М №6_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №6
# Y_ЭКСГАУСТЕР А/М №6_ЭКСГАУСТЕР А/М №6
# exhauster7
# Y_ЭКСГАУСТЕР А/М №7_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №7
# Y_ЭКСГАУСТЕР А/М №7_КОРПУС ЭКСГ. №7
# Y_ЭКСГАУСТЕР А/М №7_РОТОР ЭКСГ. №7
# Y_ЭКСГАУСТЕР А/М №7_ЭКСГАУСТЕР А/М №7
# exhauster8
# Y_ЭКСГАУСТЕР А/М №8_РОТОР ЭКСГ. №8
# Y_ЭКСГАУСТЕР А/М №8_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №8
# Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ СПВД-М10-400-5
# Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ8 ВУ1
# exhauster9
# Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №9
# Y_ЭКСГАУСТЕР А/М №9_ТР-Р ТМ-6300-10/6 ЭКСГ. №9

# %%
# Смотрим, что мы там на предсказывали
# кол-во событий М1 по оборудованию
y_m1.sum().groupby(level=0).sum()
# Out:
# Y_ЭКСГАУСТЕР А/М №4_ЗАДВИЖКА ЭКСГ. №4                           0
# Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №4           0
# Y_ЭКСГАУСТЕР А/М №4_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №4             0
# Y_ЭКСГАУСТЕР А/М №4_РОТОР ЭКСГ. №4                              0
# Y_ЭКСГАУСТЕР А/М №4_ЭКСГАУСТЕР А/М №4                           0
# Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОАППАРАТУРА ЭКСГ. №4                  0
# Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №4     0
# Y_ЭКСГАУСТЕР А/М №5_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №5         0
# Y_ЭКСГАУСТЕР А/М №5_ЗАДВИЖКА ЭКСГ. №5                           0
# Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ №1                        0
# Y_ЭКСГАУСТЕР А/М №5_РОТОР ЭКСГ. №5                              0
# Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ1    0
# Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ2    0
# Y_ЭКСГАУСТЕР А/М №5_ЭКСГАУСТЕР А/М №5                           0
# Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №5     0
# Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №5          0
# Y_ЭКСГАУСТЕР А/М №6_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №6         0
# Y_ЭКСГАУСТЕР А/М №6_ЗАДВИЖКА ЭКСГ. №6                           0
# Y_ЭКСГАУСТЕР А/М №6_ЭКСГАУСТЕР А/М №6                           0
# Y_ЭКСГАУСТЕР А/М №7_КОРПУС ЭКСГ. №7                             0
# Y_ЭКСГАУСТЕР А/М №7_РОТОР ЭКСГ. №7                              0
# Y_ЭКСГАУСТЕР А/М №7_ЭКСГАУСТЕР А/М №7                           0
# Y_ЭКСГАУСТЕР А/М №7_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №7     0
# Y_ЭКСГАУСТЕР А/М №8_РОТОР ЭКСГ. №8                              0
# Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ СПВД-М10-400-5      0
# Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ8 ВУ1    0
# Y_ЭКСГАУСТЕР А/М №8_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №8     0
# Y_ЭКСГАУСТЕР А/М №9_ТР-Р ТМ-6300-10/6 ЭКСГ. №9                  0
# Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №9          0
# dtype: int64

# %% [markdown]
# Всё по нулям. Не сложно было предвидеть такой исход - очень мало событий М1
#
# Возможно, получилось бы предсказывать события М1 по исходым фичам для поиска событий М3.
